# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as ps
import plotly.io as pio
# %matplotlib inline

# %%
df =pd.read_csv("C:/Users/HP/Desktop/InternSavy/Graduate Admission FOrm/Admission_Predict_Ver1.1.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# ## Relation between GRE score & Chances of Admit

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(1,2,figsize=(11,6))
sns.regplot(x = "GRE Score",y = "Chance of Admit ",data = df,ax = ax[0])
ax[0].set_title("Relation between GRE score & Chances of Admission")

sns.distplot(df["GRE Score"],kde=True,ax = ax[1],kde_kws = {"lw":3},hist_kws = {"linewidth":7,"alpha":0.3})
ax[1].set_title("Distribution of GRE Score")
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# With the increase of GRE score chances of Admission also increases!!
# The Number of Applicants with GRE score between 310 to 330 is higher.

# %% [markdown]
# ## Relation between TOEFL score & Chances of Admit

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(1,2,figsize=(11,6))
sns.regplot(x = "TOEFL Score",y = "Chance of Admit ",data = df,ax = ax[0])
ax[0].set_title("Relation between TOEFL score & Chances of Admission")

sns.distplot(df["TOEFL Score"],bins=18,kde=True,ax = ax[1],kde_kws = {"lw":3},hist_kws = {"linewidth":7,"alpha":0.3})
ax[1].set_title("Distribution of TOEFL Score")
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# As the TOEFL score increases the chances of Getting Admission also increases!!
# The Number of Applicants with TOEFL score between 100 to 115 is higher.

# %% [markdown]
# ## Relation between GRE Score & Chances of getting Admission with University Rating

# %%
sns.lmplot(x = "GRE Score",y = "Chance of Admit ",data = df,height=6,hue="University Rating")
plt.title("Relation between GRE Score & Chances of getting Admission with University Rating")
plt.show()

# %% [raw]
# For each case with the increase of GRE Score Chances of Getting admission also increases,but as the GRE Score increases chances of getting into a University with high rating also increases.
# For getting into a University with high rating you need a High GRE Score in most of the cases

# %% [markdown]
# ## Relation of CGPA with GRE & TOEFL Score

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(1,2,figsize=(11,6))
sns.regplot(x = "CGPA",y = "GRE Score",data = df,ax = ax[0])
ax[0].set_title("Relation between CGPA & GRE Score")

sns.regplot(x = "CGPA",y = "TOEFL Score",data = df,ax = ax[1])
ax[1].set_title("Relation between CGPA & TOEFL Score")
plt.show()

# %% [raw]
# Students who have higher CGPA also obtained higher GRE & TOEFL Score!
# So ,most of the cases CGPA & GRE Score and CGPA & TOEFL Score are kind of proportional to each other

# %%
plt.figure(figsize=(10,7))
sns.barplot(x = "SOP",y = "Chance of Admit ",linewidth=3,data = df,edgecolor="0.5")#,height=6
plt.title("Relation between SOP & Chances of getting Admission")
plt.show()

# %% [raw]
# As the quality of 'Statement of Purpose(SOP)' increases Chances of getting Admission also increases. So Relation between SOP & Chances of Admit is Proportional!!

# %%
plt.figure(figsize=(10,7))
sns.barplot(x = "LOR ",y = "Chance of Admit ",linewidth=3,data = df,edgecolor="0.5")#,height=6
plt.title("Relation between LOR & Chances of getting Admission")
plt.show()

# %% [raw]
# As the quality of 'Letter of Recommendation'(LOR) increases Chances of getting Admission also increases!! So Relation between LOR & Chances of Admit is Proportional!!

# %%
sns.lmplot(x = "GRE Score",y = "Chance of Admit ",data = df,height=6,hue="Research",markers =["v","*"])
plt.title("Relation between GRE Score & Chances of getting Admission with University Rating")
plt.show()

# %% [raw]
# If you have a Good GRE Score & experience in Research then you are on Top in the Race of getting Admission!!

# %%
df.drop("Serial No.",axis = 1,inplace=True)
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %% [markdown]
# ## Model Building

# %%
#importing necessary Libraries
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import StandardScaler

x = df.drop("Chance of Admit ",axis=1)
y = df["Chance of Admit "]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
model_dict = [["LinearRegression", LinearRegression()],["DecisionTreeRegressor" , DecisionTreeRegressor()],
             ["RandomForestRegressor", RandomForestRegressor()],["ExtraTreesRegressor", ExtraTreesRegressor()]]

for name,model in model_dict:
    model = model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    accuracy = r2_score(y_test,y_pred)
    rmse = np.sqrt(mean_squared_error(y_test,y_pred))
    print(f"The r2 score for {name} model is {accuracy*100}")
    print(f"The Root mean Squared error for {name} model is {rmse}")
    print("-"*70)
# Out:
# The r2 score for LinearRegression model is 81.88432567829629
# The Root mean Squared error for LinearRegression model is 0.06086588041578311
# ----------------------------------------------------------------------
# The r2 score for DecisionTreeRegressor model is 61.16381418092911
# The Root mean Squared error for DecisionTreeRegressor model is 0.08911789943664516
# ----------------------------------------------------------------------
# The r2 score for RandomForestRegressor model is 78.74146845965771
# The Root mean Squared error for RandomForestRegressor model is 0.06593458652331109
# ----------------------------------------------------------------------
# The r2 score for ExtraTreesRegressor model is 78.65633545232274
# The Root mean Squared error for ExtraTreesRegressor model is 0.0660664771272088
# ----------------------------------------------------------------------

# %%
experienced=df[df.Research== 1]

inexperienced=df[df.Research==0]

# %%
#%% normalization

plt.scatter(experienced["GRE Score"],experienced["TOEFL Score"],color="yellow",alpha=0.8)

plt.scatter(inexperienced["GRE Score"],inexperienced["TOEFL Score"],color="red",alpha=0.8)
plt.xlabel("GRE Score")
plt.ylabel("TOEFL Score")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##  KNN

# %%
y=df.Research.values
x_data=df.drop(["Research"],axis=1)
x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\Users\HP\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
# %% train test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state=1)

# %%
# knn model
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train,y_train)
prediction=knn.predict(x_test)

print(" {} nn score: {} ".format(3,knn.score(x_test,y_test)))
# Out:
#  3 nn score: 0.75

# %%
#%% normalization

score_list=[]
for each in range(1, 25):
    knn2=KNeighborsClassifier(n_neighbors = each)
    knn2.fit(x_train,y_train)
    score_list.append(knn2.score(x_test,y_test))
    
plt.plot(range(1,25),score_list)
plt.xlabel("k values")
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# ## SVM

# %%
#%% normalization

plt.scatter(experienced["GRE Score"],experienced["TOEFL Score"],color="yellow",alpha=0.8)
plt.scatter(inexperienced["GRE Score"],inexperienced["TOEFL Score"],color="red",alpha=0.8)
plt.xlabel("GRE Score")
plt.ylabel("TOEFL Score")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %% train test split
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state=1)

# %%
# %% SVM
from sklearn.svm import SVC

svm=SVC(random_state=1)
svm.fit(x_train,y_train)

print("score :",svm.score(x_test,y_test))
# Out:
# score : 0.8

# %% [markdown]
# ### Naive Bayes Classifier

# %%
#%% normalization

plt.scatter(experienced["GRE Score"],experienced["TOEFL Score"],color="yellow",alpha=0.8)
plt.scatter(inexperienced["GRE Score"],inexperienced["TOEFL Score"],color="red",alpha=0.8)
plt.xlabel("GRE Score")
plt.ylabel("TOEFL Score")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %% train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=1)

# %%
# %% Naive bayes 
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)

print("score :",nb.score(x_test,y_test))
# Out:
# score : 0.77

# %% [markdown]
#  ## Decision Tree Classification

# %%
# %% train test split
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
# %% Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)

print("score :",dt.score(x_test, y_test))
# Out:
# score : 0.67

# %% [markdown]
# ## Random Forest Classification

# %%
#%%  random forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 40,random_state = 1)
rf.fit(x_train,y_train)

print("random forest algo result: ",rf.score(x_test,y_test))
# Out:
# random forest algo result:  0.72

# %%
print(" {}K-Nearest Neighbors (KNN): {} ".format(3,knn.score(x_test,y_test)))

print("Support Vector Machine(SVM) Classification :",svm.score(x_test,y_test))

print("Naive Bayes Classification) :",nb.score(x_test,y_test))

print("Decision Tree Classification :",dt.score(x_test, y_test))

print("Random Forest Classification: ",rf.score(x_test,y_test))
# Out:
#  3K-Nearest Neighbors (KNN): 0.83
# Support Vector Machine(SVM) Classification : 0.77
# Naive Bayes Classification) : 0.75
# Decision Tree Classification : 0.67
# Random Forest Classification:  0.72
